# %%
# ==========================================
# WEEK 1: DATA SCIENCE ENVIRONMENT VERIFICATION
# ==========================================

# 1. Check Python Version
import sys

print("=" * 50)
print("PYTHON VERSION")
print("=" * 50)
print(sys.version)

# 2. Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression

print("\n" + "=" * 50)
print("LIBRARY VERSIONS")
print("=" * 50)
print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("Matplotlib Version:", plt.matplotlib.__version__)


# 3. NumPy Example
print("\n" + "=" * 50)
print("NUMPY EXAMPLE")
print("=" * 50)

arr = np.array([10, 20, 30, 40, 50])
print("Array:", arr)
print("Mean:", np.mean(arr))
print("Sum:", np.sum(arr))

# 4. Pandas DataFrame Example
print("\n" + "=" * 50)
print("PANDAS DATAFRAME")
print("=" * 50)

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [23, 25, 22],
    "Score": [85, 90, 88]
}

df = pd.DataFrame(data)
print(df)

# 5. Matplotlib Plot
print("\nGenerating Matplotlib Plot...")

x = [1, 2, 3, 4, 5]
y = [10, 15, 7, 20, 18]

plt.figure(figsize=(6, 4))
plt.plot(x, y, marker='o')
plt.title("Matplotlib Line Plot")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.grid(True)
plt.show()


# 8. Success Message
print("\n" + "=" * 50)
print("INSTALLATION VERIFIED SUCCESSFULLY")
print("=" * 50)
print("✓ Python Working")
print("✓ NumPy Working")
print("✓ Pandas Working")
print("✓ Matplotlib Working")

print("\nYour Google Colab environment is ready for Data Science!")
# Out:
# ==================================================
# PYTHON VERSION
# ==================================================
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#
# ==================================================
# LIBRARY VERSIONS
# ==================================================
# NumPy Version: 2.0.2
# Pandas Version: 2.2.2
# Matplotlib Version: 3.10.0
#
# ==================================================
# NUMPY EXAMPLE
# ==================================================
# Array: [10 20 30 40 50]
# Mean: 30.0
# Sum: 150
#
# ==================================================
# PANDAS DATAFRAME
# ==================================================
#       Name  Age  Score
# 0    Alice   23     85
# 1      Bob   25     90
# 2  Charlie   22     88
#
# Generating Matplotlib Plot...
# ==================================================
# INSTALLATION VERIFIED SUCCESSFULLY
# ==================================================
# ✓ Python Working
# ✓ NumPy Working
# ✓ Pandas Working
# ✓ Matplotlib Working
#
# Your Google Colab environment is ready for Data Science!
