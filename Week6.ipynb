# %%
# 1.	Measures of Central Tendency

import pandas as pd
from sklearn.datasets import load_iris
from statistics import mode
# Load Iris dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
print("First 5 rows of dataset:")
print(df.head())
# Mean (average)
mean_values = df.mean()
print("\nMean values:")
print(mean_values)
# Median (middle value)
median_values = df.median()
print("\nMedian values:")
print(median_values)
# Mode (most frequent value)
mode_values = df.mode().iloc[0]
print("\nMode values:")
print(mode_values)
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Mean values:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64
#
# Median values:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64
#
# Mode values:
# sepal length (cm)    5.0
# sepal width (cm)     3.0
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 0, dtype: float64

# %%
# 2. Measures of Dispersion

import pandas as pd
from sklearn.datasets import load_iris
# Load Iris dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
print("First 5 rows of dataset:")
print(df.head())
# Range (max - min)
range_values = df.max() - df.min()
print("\nRange values:")
print(range_values)
# Variance
variance_values = df.var()
print("\nVariance values:")
print(variance_values)
# Standard Deviation
std_values = df.std()
print("\nStandard Deviation values:")
print(std_values)
# Interquartile Range (IQR)
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print("\nInterquartile Range (IQR):")
print(IQR)
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Range values:
# sepal length (cm)    3.6
# sepal width (cm)     2.4
# petal length (cm)    5.9
# petal width (cm)     2.4
# dtype: float64
#
# Variance values:
# sepal length (cm)    0.685694
# sepal width (cm)     0.189979
# petal length (cm)    3.116278
# petal width (cm)     0.581006
# dtype: float64
#
# Standard Deviation values:
# sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64
#
# ...

# %%
# 3. Shape of Distribution

import pandas as pd
from sklearn.datasets import load_iris
# Load Iris dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
print("First 5 rows of dataset:")
print(df.head())
# Skewness (asymmetry of distribution)
skewness_values = df.skew()
print("\nSkewness values:")
print(skewness_values)
# Kurtosis (peakedness / tail heaviness)
kurtosis_values = df.kurt()
print("\nKurtosis values:")
print(kurtosis_values)
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Skewness values:
# sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# dtype: float64
#
# Kurtosis values:
# sepal length (cm)   -0.552064
# sepal width (cm)     0.228249
# petal length (cm)   -1.402103
# petal width (cm)    -1.340604
# dtype: float64

# %%
# 4. Chi-Square Test (Association Between Categorical Variables)

# Chi-Square Test

import pandas as pd
from scipy.stats import chi2_contingency

# Sample data
data = pd.DataFrame({
    'Gender': ['Male','Female','Male','Female','Male','Female'],
    'Purchase': ['Yes','No','Yes','No','No','Yes']
})

# Create contingency table
table = pd.crosstab(data['Gender'], data['Purchase'])

print("Contingency Table:")
print(table)

# Chi-Square Test
chi2, p, dof, expected = chi2_contingency(table)

print("\nChi-Square Statistic:", chi2)
print("P-value:", p)

if p < 0.05:
    print("Significant Association Exists")
else:
    print("No Significant Association")
# Out:
# Contingency Table:
# Purchase  No  Yes
# Gender
# Female     2    1
# Male       1    2
#
# Chi-Square Statistic: 0.0
# P-value: 1.0
# No Significant Association

# %%
# 5A. T-Test (Compare Means of Two Groups)

# Independent T-Test

from scipy.stats import ttest_ind

group1 = [85, 88, 90, 92, 87]
group2 = [78, 80, 82, 79, 81]

t_stat, p_value = ttest_ind(group1, group2)

print("T-Statistic:", t_stat)
print("P-value:", p_value)

if p_value < 0.05:
    print("Means are significantly different")
else:
    print("No significant difference")
# Out:
# T-Statistic: 6.000000000000004
# P-value: 0.00032339322188514703
# Means are significantly different

# %%
# 5B. ANOVA (Compare Multiple Groups)

# One-Way ANOVA

from scipy.stats import f_oneway

group1 = [85,88,90,92,87]
group2 = [78,80,82,79,81]
group3 = [65,68,70,72,69]

f_stat, p_value = f_oneway(group1, group2, group3)

print("F-Statistic:", f_stat)
print("P-value:", p_value)

if p_value < 0.05:
    print("At least one group mean differs")
else:
    print("No significant difference")
# Out:
# F-Statistic: 87.9030303030306
# P-value: 6.805027080344806e-08
# At least one group mean differs

# %%
# 5C. Z-Test (Sample Mean vs Population Mean)



import numpy as np
from statsmodels.stats.weightstats import ztest

sample = [70,72,68,75,74,71,69,73,70,72]

z_stat, p_value = ztest(sample, value=70)

print("Z-Statistic:", z_stat)
print("P-value:", p_value)

if p_value < 0.05:
    print("Sample mean differs from population mean")
else:
    print("No significant difference")
# Out:
# Z-Statistic: 1.9932317910802562
# P-value: 0.04623607144374323
# Sample mean differs from population mean

# %%
# 6A. Outlier Detection using Z-Score

import pandas as pd
import numpy as np
from scipy.stats import zscore

data = pd.DataFrame({
    'Marks':[45,50,52,48,49,51,47,46,150]
})

data['Z_Score'] = zscore(data['Marks'])

outliers = data[np.abs(data['Z_Score']) > 3]

print("Dataset:")
print(data)

print("\nOutliers:")
print(outliers)
# Out:
# Dataset:
#    Marks   Z_Score
# 0     45 -0.462218
# 1     50 -0.305829
# 2     52 -0.243273
# 3     48 -0.368384
# 4     49 -0.337106
# 5     51 -0.274551
# 6     47 -0.399662
# 7     46 -0.430940
# 8    150  2.821963
#
# Outliers:
# Empty DataFrame
# Columns: [Marks, Z_Score]
# Index: []

# %%
# 6B. Outlier Detection using IQR


import pandas as pd

data = pd.DataFrame({
    'Marks':[45,50,52,48,49,51,47,46,150]
})

Q1 = data['Marks'].quantile(0.25)
Q3 = data['Marks'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = data[
    (data['Marks'] < lower) |
    (data['Marks'] > upper)
]

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)

print("\nOutliers:")
print(outliers)
# Out:
# Q1: 47.0
# Q3: 51.0
# IQR: 4.0
#
# Outliers:
#    Marks
# 8    150

# %%
# 6C. Grubbs' Test

# !pip install outlier-utils

# %%
from outliers import smirnov_grubbs as grubbs

data = [45,50,52,48,49,51,47,46,150]

print("Original Data:")
print(data)

result = grubbs.test(data)

print("\nAfter Removing Outlier:")
print(result)
# Out:
# Original Data:
# [45, 50, 52, 48, 49, 51, 47, 46, 150]
#
# After Removing Outlier:
# [47 46]
